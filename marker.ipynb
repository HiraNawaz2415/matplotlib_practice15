# %% [markdown]
# <h1>Matplotlib Markers</h1>
# use the keyword argument marker to emphasize each point with a specified marker:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, marker = '*')
# make each point with start
plt.show()

# %% [markdown]
# <h1>Format Strings fmt  </h1>
# syntax:
#
# marker|line|color
# <b> Line Syntax	Description
# '-'	Solid line
# ':'	Dotted line
# '--'	Dashed line
# '-.'	Dashed/dotted line</b>
# Color Syntax	Description
# 'r'	Red
# 'g'	Green
# 'b'	Blue
# 'c'	Cyan
# 'm'	Magenta
# 'y'	Yellow
# 'k'	Black
# 'w'	White

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, '*--y')
plt.show()

# %% [markdown]
# <h1>Marker Size</h1>
# use the keyword argument markersize or the shorter version, ms to set the size of the markers:
# Example
# Set the size of the markers to 10

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 10)
plt.show()

# %% [markdown]
# <h1>Marker Color</h1>
# use the keyword argument markeredgecolor or the shorter mec to set the color of the edge of the markers
# Example
# Set the EDGE color to red

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r')
plt.show()

# %% [markdown]
# use the keyword argument markerfacecolor or the shorter mfc to set the color inside the edge of the markers:
#
# Example:Set the FACE color to green

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mfc = 'g')
plt.show()

# %% [markdown]
# Example
# Set the color of both the edge and the face to red:
#
# import matplotlib.pyplot as plt
# import numpy as np
#
# ypoints = np.array([3, 8, 1, 10])
#
# plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r', mfc = 'r')
# plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'c', mfc = 'c')
plt.show()
